# %% [markdown]
# # String

# %%
str1="Good Morning"

# %%
#Access the character d
str1[3]
# Out:
# 'd'

# %%
str1[-4]
# Out:
# 'n'

# %%
str1[0]
# Out:
# 'G'

# %% [markdown]
# ## masked mob no

# %%
mobile="9876543212"
masked= mobile[:2]+"******"+mobile[-2:]
print (masked)
# Out:
# 98******12

# %%
# formatting
song= "shape OF you"
artist="SUBESAN t p"
formatted=f"{song.title()} , {artist.title()}" # title convert each word 1st letter caps
print(formatted)
# Out:
# Shape Of You , Subesan T P

# %%
# replace
location="Erode"
fixed_location=location.replace("Erode","Gobi") # erode is old , replaced by new gobi
print(fixed_location)
# Out:
# Gobi

# %%
#  split 
message="your bus booking id is :MGB3451.Keep it confidential"
booking_id=message.split(":")[1]
print(booking_id)
# Out:
# MGB3451.Keep it confidential

# %%
message="your bus booking id is : MGB3451.Keep it confidential"
booking_id=message.split(":")[1].split(".")[0].strip() # strip removes unwanted spaces
print(booking_id)
# Out:
# MGB3451

# %%
promo="use mani345 to get 45% discount on your first order"
if "mani345" in promo:
    print("discount applied")
# Out:
# discount applied

# %%
# find position of a word
feedback="We reached earlier on express"
print("position is :",feedback.find("express"))
# Out:
# position is : 22

# %%
# extract first letter last letter
# done by using FOR LOOP
name="subesan rohit"
initials=([word[0].upper() for word in name.split()])
print(initials)
# Out:
# ['S', 'R']

# %%
# extract first letter last letter
# done by using FOR LOOP
name="subesan rohit"
initials="".join([word[0].upper() for word in name.split()])
print(initials)
# Out:
# SR

# %%
# count the words
word1="the week with fine eveenings and fresh air was pleasure"
word_count=len(word1.split())# as the words are splitted by space 
print(word_count)
# Out:
# 10

# %%
print(str1[1])
# Out:
# o

# %%
str1[5]
# Out:
# 'M'

# %%
str1[9]
# Out:
# 'i'

# %%
str1[-1]
# Out:
# 'g'

# %%
str1[-6]
# Out:
# 'o'

# %%
str1[1]
# Out:
# 'o'

# %%
str1[-9]
# Out:
# 'd'

# %% [markdown]
# # String Slicing

# %%
str2="HELLO PYTHON"

# %%
str2[:] # Accessing all the char in string
# Out:
# 'HELLO PYTHON'

# %%
str2[2:]
# Out:
# 'LLO PYTHON'

# %%
str2[:7]
# Out:
# 'HELLO P'

# %%
str2[4:9]
# Out:
# 'O PYT'

# %%
str2[4:12]
# Out:
# 'O PYTHON'

# %%
str2[0:9:2]
# Out:
# 'HLOPT'

# %%
str2[::2]
# Out:
# 'HLOPTO'

# %%
str2[3:10:3]
# Out:
# 'LPH'

# %%
str2[::-1] # Reverse the string using slicing
# Out:
# 'NOHTYP OLLEH'

# %% [markdown]
# # String concatenation

# %%
fname="Subi "
lname="kutty"

# %%
full_name=fname+lname
print(full_name)
# Out:
# Subi kutty

# %%
x="Subesh"+" "+"kutty"
print(x)
# Out:
# Subesh kutty

# %% [markdown]
# # Membership Operator

# %%
fname
# Out:
# 'Subi '

# %%
"i"in fname
# Out:
# True

# %%
"s"in fname
# Out:
# False

# %%
"a" not in fname
# Out:
# True

# %%
"e"not in fname
# Out:
# True

# %%
"B" not in fname
# Out:
# True

# %% [markdown]
# # String Functions

# %%
str1='good morning'

# %%
str1.upper()
# Out:
# 'GOOD MORNING'

# %%
str2="HELLO PYTHON"

# %%
str2.lower()
# Out:
# 'hello python'

# %%
str2.count("O")
# Out:
# 2

# %%
str2.count("E")
# Out:
# 1

# %%
str2.count("e")
# Out:
# 0

# %%
str2.index("Y") #returns index value for the given argument
# Out:
# 7

# %%
str2.index("H") # returns first occourence of char
# Out:
# 0

# %%
str2.index("L")
# Out:
# 2

# %%
str3="              DATAMITES                "

# %%
str3.strip() # by default it removes spaces before and end of the sting
# Out:
# 'DATAMITES'

# %%
str4="*******************Datamites******************"

# %%
str4.strip("*")
# Out:
# 'Datamites'

# %%
str4.lstrip()
# Out:
# '*******************Datamites******************'

# %%
str4.rstrip()
# Out:
# '*******************Datamites******************'

# %%
str5="one two three four five"

# %%
str5.split()
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
str6="subi:allied :suki:mahi:praveen:athu"

# %%
str6.split(":")
# Out:
# ['subi', 'allied ', 'suki', 'mahi', 'praveen', 'athu']

# %%
str7="welcome to datamites at Maratahalli branch"

# %%
str7.partition("to") # Partition the string into three parts
# Out:
# ('welcome ', 'to', ' datamites at Maratahalli branch')

# %%
str7.startswith("we") # Returns True if S starts with the specific prefix, False otherwise
# Out:
# True

# %%
str7.endswith("t")
# Out:
# False

# %%
a=7
b=3
print("a+b=",a+b)
# Out:
# a+b= 10

# %% [markdown]
# # Arithmetic Operators

# %%
print("a-b=",a-b)
# Out:
# a-b= 4

# %%
print("a*b=",a*b)
# Out:
# a*b= 21

# %%
print("a/b=",a/b)
# Out:
# a/b= 2.3333333333333335

# %%
print("a power of b =",a**b) # power represented by a**b
# Out:
# a power of b = 343

# %%
print("a mod of b =",a%b) #returms the remainder value
# Out:
# a mod of b = 1

# %%
print("a floor of b = " , a//b) # only integer, removes decimals
# Out:
# a floor of b =  2

# %% [markdown]
# # Logical Operators

# %%
a=True
b=False
print("a=",a)
print("b=",b)
print("a and b= ",a and b)
print("a or b = ",a or b)
print("not a =",not a)
# Out:
# a= True
# b= False
# a and b=  False
# a or b =  True
# not a = False
