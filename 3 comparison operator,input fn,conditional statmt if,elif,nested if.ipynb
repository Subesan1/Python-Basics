# %% [markdown]
# # Comparison operator

# %%
x=5
y=20
print("x>y",x>y)
print ("x<y",x<y)
print("x==y",x==y)
print("x!=y",x!=y) # 5 is not equal to 20
print("x>=y",x>=y) # atleast meet any 1 condition ether it should be greater or exual
# Out:
# x>y False
# x<y True
# x==y False
# x!=y True
# x>=y False

# %% [markdown]
# # Input Function()

# %%
user_name=input("enter the user name")
print(user_name)
print("the data type of user_name is :",type(user_name))
# Out:
# enter the user name subi
# subi
# the data type of user_name is : <class 'str'>

# %%
age=input("enter the value of age")
print(age)
print("the data type of age is :",type(age))
# Out:
# enter the value of age 21
# 21
# the data type of age is : <class 'str'>

# %%
age=int(input("enter the value of age"))
print(age)
print("the data type of age is :",type(age))
# Out:
# enter the value of age 21
# 21
# the data type of age is : <class 'int'>

# %%
marks=float(input("enter the marks"))
print("marks=",marks)
print("the type of mark is",type(marks))
# Out:
# enter the marks 77.654
# marks= 77.654
# the type of mark is <class 'float'>

# %% [markdown]
# # Conditional Statements

# %% [markdown]
# # 1. If statement

# %%
value=int(input("enter the number"))
if value<5:
    print("the value is lesser than 5")
print("this statement is independent statement")
# Out:
# enter the number 5
# this statement is independent statement

# %%
value=int(input("enter the numeric value"))
if value<5:
    print("the value is lesser than 5")
print("this statement is independent statement")
# Out:
# enter the numeric value 3
# the value is lesser than 5
# this statement is independent statement

# %%
age=int(input("enter the value of age"))
if age>=18:
    print("Executes if block,if condition is true")
    print("you are an adult")
# Out:
# enter the value of age 21
# Executes if block,if condition is true
# you are an adult

# %% [markdown]
# # 2. If-else Statement

# %%
print("write a program to check whether the given number is positive or negative")
num=int(input("enter the number"))

if num>0:
    print("the number is +ve")
else:
    print("the number is -ve")

print("end of the program")
# Out:
# write a program to check whether the given number is positive or negative
# enter the number 6
# the number is +ve
# end of the program

# %%
print("write a program to check whether the given number is positive or negative")
num=int(input("enter the number"))

if num>0:
    print("the number is +ve")
else:
    print("the number is -ve")

print("end of the program")
# Out:
# write a program to check whether the given number is positive or negative
# enter the number -3
# the number is -ve
# end of the program

# %%
name="SUBI"
if "r" in name:
    print("the character r is present")
else:
    print("the character r is not present")
# Out:
# the character r is not present

# %%
print("write a program to check whether the given number is odd or even")
num=int(input("enter the number"))

if num%2==0:
        print("even number")
else:
        print("odd number")
# Out:
# write a program to check whether the given number is odd or even
# enter the number 4
# even number

# %%
print("write a program to validate username and password")
user_name="rohit"
password="rohit2009"

if user_name=="rohit" and password=="rohit2009":
    print("both user name and password are correct")
else:
    print("Incorrect Usernsme or password")
# Out:
# write a program to validate username and password
# both user name and password are correct

# %% [markdown]
# # if-elif-else Block

# %%
print("write a program to check whether the given number is positive or negative or zero")
num=int(input("enter the number"))

if num>0:
    print("the number is +ve")
elif num<0:
    print("the number is -ve")
else :
    print("the number is zero")
    
print("end of the program")
# Out:
# write a program to check whether the given number is positive or negative or zero
# enter the number 21
# the number is +ve
# end of the program

# %%
print("write a program to check whether the given number is positive or negative or zero")
num=int(input("enter the number"))

if num>0:
    print("the number is +ve")
elif num<0:
    print("the number is -ve")
else :
    print("the number is zero")
    
print("end of the program")
# Out:
# write a program to check whether the given number is positive or negative or zero
# enter the number 0
# the number is zero
# end of the program

# %%
score=int(input("enter the score"))

if score>=90:
    print("Grade A+")
elif score>=80:
    print("Grade A")
elif score>=75:
    print("Grade B+")
elif score>=70:
    print("Grade B")
elif score>=60:
    print("Grade C")
else:
    print("FAILED")
# Out:
# enter the score 74
# Grade B

# %% [markdown]
# # Nested if ststement

# %%
attendance=int(input("enter the attendance value"))

if attendance>=75:
    marks=float(input("enter the marks"))
    if marks>60:
        print("PASS")
    else :
        print("Failed")

else:
    print("Not eligible to write exams")
# Out:
# enter the attendance value 83
# enter the marks 74
# PASS

# %%
a=13.66
c=int (a) # convert float to integer
print(c,type(c))
s=str(a) #convert float to string
print(s,type(s))
d=bool(a) # convert float to boolean
print(d,bool(d))
# Out:
# 13 <class 'int'>
# 13.66 <class 'str'>
# True True

# %%
b=45
z=float(b)
print(z,type(z))
# Out:
# 45.0 <class 'float'>

# %%
pwd
# Out:
# 'C:\\Users\\HP\\subi python'

# %% [markdown]
# ## if elif nestedif form DATA ENGG YOUTUBE

# %%
age=2
if age>=19:
    print("you can vote")
else:
    print("you can't vote")
# Out:
# you can't vote

# %%
# elif
mark=50.5
if mark>=90:
    print("Grade A")
elif mark>=70:
    print("Grade B")
elif mark>=50:
    print ("Grade C")
else:
    print("Fail")
# Out:
# Grade C

# %%
# nested if 
age=20
has_lisence="yes"

if age>=18:
    if has_lisence == "yes":
        print("you can drive")
    else:
        print ("go and take lisence")
else:
    print("you are too young for drive")
# Out:
# you can drive

# %%
mark=69
attendence=80
if mark>=60 and attendence >=80: # and checks both condn 
    print("eligible for exam")
else:
    print("not eligible for exam")
# Out:
# eligible for exam

# %%
#real tym if use
recharge=200      #or executes if any 1 condn true
data=1.5
if recharge>=399 or data>=1.5:
    print("get bonus of 4gb data")
else:
    print("no bonus applied currently")
# Out:
# get bonus of 4gb data

# %%
order_amount=1000 # and(put and in bracket) , or used in same condn
day="sun"
membership="no"

if (order_amount>=1000 and day in ['sat','sun']) or membership=="gold":
    print("45% discount")
else:
    print("No discount")
# Out:
# 45% discount
