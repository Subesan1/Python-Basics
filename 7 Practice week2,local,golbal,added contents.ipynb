# %% [markdown]
# # list

# %%
game_over=['bb','fb','tt','vb','ct']

# %%
type(game_over)
# Out:
# list

# %%
game_over[:]
# Out:
# ['bb', 'fb', 'tt', 'vb', 'ct']

# %%
game_over[0]="basket"
game_over
# Out:
# ['basket', 'fb', 'tt', 'vb', 'ct']

# %%
game_over[3]
# Out:
# 'vb'

# %%
game_over.append("mani")
game_over
# Out:
# ['basket', 'fb', 'tt', 'vb', 'ct', 'mani']

# %%
game_over.remove('vb')
game_over
# Out:
# ['basket', 'fb', 'tt', 'ct', 'mani']

# %%
game_over=['bb','fb','tt','vb','ct','kb']

# %%
for game in game_over:
    if game =='tt':
        break
print(game_over)
# Out:
# ['bb', 'fb', 'tt', 'vb', 'ct', 'kb']

# %%
game_over.insert(6,'f')
game_over
# Out:
# ['bb', 'fb', 'tt', 'vb', 'ct', 'kb', 'f', 'f']

# %%
game_over.remove("f")

# %%
game_over
# Out:
# ['bb', 'fb', 'tt', 'vb', 'ct', 'kb', 'f']

# %%
game_over[5]
# Out:
# 'kb'

# %%
game_over[-6]
# Out:
# 'bb'

# %%
game_over[3]="new"
game_over
# Out:
# ['bb', 'fb', 'tt', 'new', 'ct', 'kb']

# %%
len(game_over)
# Out:
# 6

# %%
game_over[::-1]
# Out:
# ['kb', 'ct', 'new', 'tt', 'fb', 'bb']

# %%
game_over[-5:-1:1]
# Out:
# ['fb', 'tt', 'new', 'ct']

# %%
game_over[-5:-3]
# Out:
# ['fb', 'tt']

# %%
game_over[2:4]
# Out:
# ['tt', 'vb']

# %%
'mani' not in game_over
# Out:
# True

# %%
'tt' in game_over
# Out:
# True

# %% [markdown]
# ## string IMMUTABLE , LIST MUTABLE

# %%
a="maram"
a[3]=R
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 2
#       1 a="maram"
# ----> 2 a[3]=R
#
# NameError: name 'R' is not defined

# %%
a=["maram","kaathu",'climate','traffic']

# %%
a[3]="green"
a
# Out:
# ['maram', 'kaathu', 'climate', 'green']

# %% [markdown]
# # nested list

# %%
n=[3,4,['d','q','r','g'],5,[7,97,0],2,4]

# %%
len(n)
# Out:
# 7

# %%
n[6]
# Out:
# 4

# %%
n[-3][-2]
# Out:
# 97

# %% [markdown]
# # list fn

# %%
a=['b','c','e','f','g']

# %%
a.append('h')
a
# Out:
# ['b', 'c', 'e', 'f', 'g', 'h', 'm', 'm', 'm', 'm', 'h', 'm', 'h']

# %%
a.extend('m')
a
# Out:
# ['b', 'c', 'e', 'f', 'g', 'v', 'h', 'h', 'm', 'm']

# %%
a.count('h')
# Out:
# 2

# %%
a.index('b')
# Out:
# 0

# %%
a.insert(7,'v')

# %%
a
# Out:
# ['b', 'c', 'e', 'f', 'g', 'v', 'h', 'v', 'h', 'm', 'm']

# %%
a.remove("m")
a
# Out:
# ['b', 'c', 'e', 'f', 'g', 'v', 'h', 'v', 'h', 'm']

# %%
a.remove('v')
a
# Out:
# ['b', 'c', 'e', 'f', 'g', 'v', 'm']

# %%
a.clear()

# %%
a
# Out:
# []

# %% [markdown]
# # tuple

# %%
tup=(1,2,3,"a","b","c")

# %%
type(tup)
# Out:
# tuple

# %%
tup[2]
# Out:
# 3

# %%
tup[2:4:1]
# Out:
# (3, 'a')

# %%
'c' in tup
# Out:
# True

# %%
tup[5]="y"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 tup[5]="y"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # set

# %%
s={5,6,1,4,9,0,11,24,54,2,5,2,1,4,6,5,2,7,667,998,224,556,78,"a","C"}

# %%
len(s)
# Out:
# 18

# %%
s
# Out:
# {0, 1, 11, 2, 224, 24, 4, 5, 54, 556, 6, 667, 7, 78, 9, 998, 'C', 'a'}

# %%
s[5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 s[5]
#
# TypeError: 'set' object is not subscriptable

# %%
5 in s
# Out:
# True

# %%
s.add(9)
s
# Out:
# {0, 1, 11, 2, 224, 24, 4, 5, 54, 556, 6, 667, 7, 78, 9, 998, 'C', 'a'}

# %%
s.remove(224)
s
# Out:
# {0, 1, 11, 2, 24, 4, 5, 54, 556, 6, 667, 7, 78, 9, 998, 'C', 'a'}

# %%
s.update([3,8])
s
# Out:
# {0, 1, 11, 2, 24, 3, 4, 5, 54, 556, 6, 667, 7, 78, 8, 9, 998, 'C', 'a'}

# %%
s
# Out:
# {0, 1, 11, 2, 3, 4, 5, 54, 556, 6, 667, 7, 78, 8, 9, 998, 'C', 'a'}

# %%
s="HELLO PYTHON"

# %%
s[-1:-5:-1]
# Out:
# 'NOHT'

# %%
s[-5:-1:-1]
# Out:
# ''

# %%
a={1,2,3,4,5,"c"}
b={5,4,3,7,8,"D"}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 7, 8, 'D', 'c'}

# %%
a.intersection(b)
# Out:
# {3, 4, 5}

# %%
a.difference(b)
# Out:
# {1, 2, 'c'}

# %% [markdown]
# # Dictionary

# %%
a={"age":21,"stay":"pg","shop":"mall","center":"datamites"}

# %%
type(a)
# Out:
# dict

# %%
a.values()
# Out:
# dict_values([21, 'pg', 'mall', 'datamites'])

# %%
a.update({"mode":"a/c bus"})
a
# Out:
# {'age': 21,
#  'stay': 'pg',
#  'shop': 'mall',
#  'center': 'datamites',
#  'mode': 'a/c bus'}

# %%
a["age"]=20
a
# Out:
# {'age': 20,
#  'stay': 'pg',
#  'shop': 'mall',
#  'center': 'datamites',
#  'mode': 'a/c bus'}

# %%
a["State"]="TN"
a
# Out:
# {'age': 20,
#  'stay': 'pg',
#  'shop': 'mall',
#  'center': 'datamites',
#  'mode': 'a/c bus',
#  'State': 'TN'}

# %%
a.pop("shop")
a
# Out:
# {'age': 20,
#  'stay': 'pg',
#  'center': 'datamites',
#  'mode': 'a/c bus',
#  'State': 'TN'}

# %%
a.keys()
a
# Out:
# {'age': 20,
#  'stay': 'pg',
#  'center': 'datamites',
#  'mode': 'a/c bus',
#  'State': 'TN'}

# %%
a.values()
a
# Out:
# {'age': 20,
#  'stay': 'pg',
#  'center': 'datamites',
#  'mode': 'a/c bus',
#  'State': 'TN'}

# %%
a.update({"task":"walk","enhance":"refresh","tym":"evng"})
a
# Out:
# {'age': 20,
#  'stay': 'pg',
#  'center': 'datamites',
#  'mode': 'a/c bus',
#  'State': 'TN',
#  'task': 'walk',
#  'enhance': 'refresh',
#  'tym': 'evng'}

# %%
a.items()
# Out:
# dict_items([('age', 20), ('stay', 'pg'), ('center', 'datamites'), ('mode', 'a/c bus'), ('State', 'TN'), ('task', 'walk'), ('enhance', 'refresh'), ('tym', 'evng')])

# %%
del a['mode']
a
# Out:
# {'age': 20,
#  'stay': 'pg',
#  'center': 'datamites',
#  'State': 'TN',
#  'task': 'walk',
#  'enhance': 'refresh',
#  'tym': 'evng'}

# %% [markdown]
# # WHILE LOOP

# %%
i=0
while i<5:
    print('s')
    i=i+1
print('the end')
# Out:
# s
# s
# s
# s
# s
# the end

# %%
i=1
while i<9:
    print(i*2-1)
    i=i+1
print('end')
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# end

# %%
i=0
while i<7:
    print(i*2)
    i=i+1
print('end')
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# 12
# end

# %%
i=1
while i<13:
    cube=i*i*i
    print("cube is",cube)
    if cube==1331:
        break
    i=i+1
print("end")
# Out:
# cube is 1
# cube is 8
# cube is 27
# cube is 64
# cube is 125
# cube is 216
# cube is 343
# cube is 512
# cube is 729
# cube is 1000
# cube is 1331
# end

# %%
i=1
while i<9:
    square=i*i
    if square==16:
        print("skip sq 16")
        i=i+1
        continue
    print('sq value is',square)
    i=i+1
print('end')
# Out:
# sq value is 1
# sq value is 4
# sq value is 9
# skip sq 16
# sq value is 25
# sq value is 36
# sq value is 49
# sq value is 64
# end

# %%
i=0
while i<7:
    cube=i*i*i
    if cube==27:
        print("skip cube",cube)
        i=i+1
        continue
    print('cube val is',cube)
    i=i+1
print('end')
# Out:
# cube val is 0
# cube val is 1
# cube val is 8
# skip cube 27
# cube val is 64
# cube val is 125
# cube val is 216
# end

# %%
i=2
while i<5:
    print(i+i)
    i=i+1
print("end")
# Out:
# 4
# 6
# 8
# end

# %% [markdown]
# # for loop

# %%
places=['park','beach','water game','evng']
for b in places:
    print(b)
# Out:
# park
# beach
# water game
# evng

# %%
places=['park','beach','water game','evng']
for b in places:
    if b=='water game':
        break
    print(b)
# Out:
# park
# beach

# %%
plan=['park','mall','travel','explore','fun']
for f in plan:
    print(f)
# Out:
# park
# mall
# travel
# explore
# fun

# %%
plan=['park','mall','travel','explore','fun']
for f in plan:
    if f=='mall':
        continue
    print(f)
# Out:
# park
# travel
# explore
# fun

# %%
vov=["a","e","i","o","u"]
for g in vov:
    if g=="o":
        break
    print(g)
# Out:
# a
# e
# i

# %% [markdown]
# # range

# %%
for v in range (9,24,5):
    print(v)
# Out:
# 9
# 14
# 19

# %%
str="hi subu"
for s in str:
    print(s)
# Out:
# h
# i
#
# s
# u
# b
# u

# %%
d={1:21,2:22,3:23}
for h in d:
    print(h)
# Out:
# 1
# 2
# 3

# %%
d={1:21,2:22,3:23}
for h in d:
    print(f'{h}:{d[h]}')
# Out:
# 1:21
# 2:22
# 3:23

# %% [markdown]
# # nested for loop

# %%
for e in [1,2,3,4]:
    for f in ['a','d','s']:
        print(e,f)
# Out:
# 1 a
# 1 d
# 1 s
# 2 a
# 2 d
# 2 s
# 3 a
# 3 d
# 3 s
# 4 a
# 4 d
# 4 s

# %%
for i in range(1,26):
    if i%4==0:
        print(i)
# Out:
# 4
# 8
# 12
# 16
# 20
# 24

# %%
names=['san','star','walk','talk']
caps=[]
for name in names:
    caps.append(name.upper())
    print(caps)
# Out:
# ['SAN']
# ['SAN', 'STAR']
# ['SAN', 'STAR', 'WALK']
# ['SAN', 'STAR', 'WALK', 'TALK']

# %% [markdown]
# # functions

# %%
def average_mark(a,b):
    average_mark=a+b/2
    return average_mark

# %%
average_mark(5,6)
# Out:
# 8.0

# %%
# Function to swap two numbers
def swap_numbers(a, b):
    return b, a  # returning swapped values

# Main program
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))

print("Before swapping: x =", x, " y =", y)

# Call the function
x, y = swap_numbers(x, y)

print("After swapping:  x =", x, " y =", y)
# Out:
# Enter first number:  1
# Enter second number:  3
# Before swapping: x = 1  y = 3
# After swapping:  x = 3  y = 1

# %%
# Function to calculate average marks
def calculate_average(marks):
    total = sum(marks)           # Sum of all marks
    average = total / len(marks) # Average calculation
    return average

# Main program
def main():
    # Taking input for number of subjects
    n = int(input("Enter number of subjects: "))
    
    marks = []
    for i in range(n):
        mark = float(input(f"Enter mark for subject {i+1}: "))
        marks.append(mark)

    avg = calculate_average(marks)
    print("\n--- Result ---")
    print(f"Marks: {marks}")
    print(f"Average Marks: {avg:.2f}")

# Run program
if __name__ == "__main__":
    main()
# Out:
# Enter number of subjects:  3
# Enter mark for subject 1:  4
# Enter mark for subject 2:  5
# Enter mark for subject 3:  6
# --- Result ---
# Marks: [4.0, 5.0, 6.0]
# Average Marks: 5.00

# %%
def swap_num(a,b):
    return b,a

# %%
swap_num(6,5)
# Out:
# (5, 6)

# %% [markdown]
# # Variable scope Local , global var

# %%
def order():
    food="Hyderabad Briyani" #local var
    print("your order is:",food)
order()
# Out:
# your order is: Hyderabad Briyani

# %%
food="curd rice" #global var
def order():
    print("you ordered :",food)

# %%
order()
# Out:
# you ordered : curd rice

# %% [markdown]
# ## Variable scope ENCLOSING

# %%
def card():
    discount=10 # indentation is very important to consider it prints only when indentn comes similar

    def checkout():
        print("discount applied:",discount)
       
    checkout() # to get checkout() it should be straight to its def

card() # similarly for card
# Out:
# discount applied: 10

# %%
# global
user_id="subu451"
def homepage():
    print("welcome:",user_id)
def profile_page():
    print("welcome to profile page:",user_id)
homepage()
profile_page()
# Out:
# welcome: subu451
# welcome to profile page: subu451

# %%
# print(__file__) works on pycharm shows path

# %% [markdown]
# ### operators in python

# %%
amount = 1234
tax = amount* 0.18
total = amount + tax
print(total)
if total >1000:
    discount =total*0.10
    total -= discount
print(total)
# Out:
# 1456.12
# 1310.5079999999998

# %%
amt=1055
tax= amt*0.18
total=amt+tax
print(total)
if total>1000:
    discount = total*.1
    total -=discount
print(total)
# Out:
# 1244.9
# 1120.41

# %%
age=64
student="yes"

if age>=60 or student=="yes":
    print("yes discount")
else:
    print("no discount")
# Out:
# yes discount
